# %% [markdown]
# # A minimal example

# %% [markdown]
# Load some standard configuration and packages

# %%
# %run ./jupyter_startup.ipy
# Out:
# Load standard packages and some magic commands, set up logger and matplotlib rcParams.
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%important With custom title
# This is a **new** *cell magic command* 😊
# Out:
# <div style='border:thick solid red; padding:10px'>                      <div style='color:red; font-size:x-large; text-decoration:underline'><p>With custom title</p></div>                      <div style='font-weight:bold; font-size:large'><p>This is a <strong>new</strong> <em>cell magic command</em> 😊</p></div></div>

# %%
from tqdm.auto import tqdm
from time import sleep

# %%
for i in tqdm(range(20)):
    sleep(.1)
# Out:
# 100%|██████████| 20/20 [00:02<00:00,  9.77it/s]

# %%
alert('All done')
